# %%
import pandas as pd
from pathlib import Path

# %%
file_path = Path(r"D:\Projects\etl-data\data\business_partner_data\List of Business Partners.xlsx")

df = pd.read_excel(file_path)
df.columns

df = df[['BP Code', 'BP Name', 'Team Name', 'Bill-to Street', 'Ship-to Street', 'Creation Date']]

# %%
df["Team Name"].unique()
# Out:
# <StringArray>
# [                           nan,                  'Doi 1 MNDB1',
#         'Doi ban hang mien Bac',                 'Doi 4 MBDB 3',
#                    'Đội 2 MBĐB',                   'Đội 1 MNĐB',
#                    'Đội 4 MBĐB',                  'Doi 2 MNDB3',
#                     'Đội 3 MN1',                  'Doi 2 MNDB2',
#  ...
#                       'Đội SX2',            'Đội thu mua củ mì',
#          'Đội sản xuất bột sữa',              'Đội QA Tây Ninh',
#      'Đội kế hoạch nguyên liệu',         'Đội quản lý bán hàng',
#  'Đội sản xuất 2 ( đường nha )',       'Đội sản xuất Hải Dương',
#         'Doi ke hoach san xuat',          'Truong ban tinh bot']
# Length: 317, dtype: str
