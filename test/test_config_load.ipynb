# %%
import pandas as pd
from pathlib import Path
from sqlalchemy import create_engine

# %%
file = Path(r"C:\Users\Admin\Desktop\Import PL\pl_data.csv")
df = pd.read_csv(file)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21336\545150067.py:2: DtypeWarning: Columns (0: profit_center_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %%
df["date"] = pd.to_datetime(df["date"])
df["source_file"] = "old_db"

# %%
engine = create_engine("postgresql+psycopg://postgres:duong1234@localhost:5432/daesang_db_test")
engine1 = create_engine("postgresql+psycopg://postgres:duong1234@localhost:5432/daesang_db")

# %%
df.to_sql(
    name="profit_and_loss",
    schema="staging",
    index=False,
    if_exists="append", 
    con=engine,
    chunksize=10000
)
# Out:
# -92
